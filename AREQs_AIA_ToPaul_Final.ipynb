# %%
from os.path import expanduser, pathsep, dirname, realpath
import sys
# -- todo: Uncomfortable for two different imports from the same module to be handled differently...
from utility_funcs.search import get_server_info, search_for_profile
import utility_funcs.logger_yaml as log

LOG_CONFIG_FILE = 'logging.yaml'+pathsep+dirname(realpath(sys.argv[0]))+'/logging.yaml'
CONFIG_FILE = dirname(realpath(sys.argv[0]))+'/config.yaml'+pathsep+'~/.jira/config.yaml'
QUERIES_FILE = dirname(realpath(sys.argv[0]))+'/queries.yaml'+pathsep+'~/.jira/queries.yaml'
SCENARIO_FILE = 'scenarios.yaml'+pathsep+dirname(realpath(sys.argv[0]))+'/scenarios.yaml'

log_file = log.logging.getLogger("file")
log.setup_logging(LOG_CONFIG_FILE, override={'handlers': {'info_file_handler': {'filename': 'jupyter.log'}}})

from jira_class import Jira, get_query
from navigate import *
from jira.exceptions import JIRAError
jira = Jira('jira01', CONFIG_FILE, log.logger)
# Out:
# 2017-11-07 11:11:44,105 - root - INFO - Using logging configuration file C:\Users\pfhanchx\Documents\otc_androidplanning-toolbox\logging.yaml
# 2017-11-07 11:11:44,434 - root - INFO - Using JIRA server jira01, 'https://jira01.devtools.intel.com'
# 2017-11-07 11:11:44,435 - root - INFO - Connecting to https://jira01.devtools.intel.com using verified connection.

# %%
jira.issue("AREQ-1234")
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AREQ-11225</th>
#       <td>AREQ-11225</td>
#     </tr>
#     <tr>
#       <th>AREQ-11429</th>
#       <td>AREQ-11429</td>
#     </tr>
#     <tr>
#       <th>AREQ-17028</th>
#       <td>AREQ-17028</td>
#     </tr>
#     <tr>
#       <th>AREQ-17029</th>
#       <td>AREQ-17029</td>
#     </tr>
#     <tr>
#       <th>AREQ-17030</th>
#       <td>AREQ-17030</td>
#     </tr>
#     <tr>
#       <th>AREQ-17031</th>
#       <td>AREQ-17031</td>
#     </tr>
#     <tr>
#       <th>AREQ-17032</th>
#       <td>AREQ-17032</td>
#     </tr>
#     <tr>
#       <th>AREQ-17033</th>
#       <td>AREQ-17033</td>
#     </tr>
#     <tr>
#       <th>AREQ-17034</th>
#       <td>AREQ-17034</td>
#     </tr>
#     <tr>
#       <th>AREQ-17035</th>
#       <td>AREQ-17035</td>
#     </tr>
#     <tr>
#       <th>AREQ-17036</th>
#       <td>AREQ-17036</td>
#     </tr>
#     <tr>
#       <th>AREQ-17037</th>
#       <td>AREQ-17037</td>
#     </tr>
#     <tr>
#       <th>AREQ-17038</th>
#       <td>AREQ-17038</td>
#     </tr>
#     <tr>
#       <th>AREQ-17039</th>
#       <td>AREQ-17039</td>
#     </tr>
#     <tr>
#       <th>AREQ-17040</th>
#       <td>AREQ-17040</td>
#     </tr>
#     <tr>
#       <th>AREQ-17041</th>
#       <td>AREQ-17041</td>
#     </tr>
#     <tr>
#       <th>AREQ-17042</th>
#       <td>AREQ-17042</td>
#     </tr>
#     <tr>
#       <th>AREQ-17043</th>
#       <td>AREQ-17043</td>
#     </tr>
#     <tr>
#       <th>AREQ-17044</th>
#       <td>AREQ-17044</td>
#     </tr>
#     <tr>
#       <th>AREQ-17045</th>
#       <td>AREQ-17045</td>
#     </tr>
#     <tr>
#       <th>AREQ-17046</th>
#       <td>AREQ-17046</td>
#     </tr>
#     <tr>
#       <th>AREQ-17047</th>
#       <td>AREQ-17047</td>
#     </tr>
#     <tr>
#       <th>AREQ-17048</th>
#       <td>AREQ-17048</td>
#     </tr>
#     <tr>
#       <th>AREQ-17049</th>
#       <td>AREQ-17049</td>
#     </tr>
#     <tr>
#       <th>AREQ-17050</th>
#       <td>AREQ-17050</td>
#     </tr>
#     <tr>
#       <th>AREQ-17051</th>
#       <td>AREQ-17051</td>
#     </tr>
#     <tr>
#       <th>AREQ-17052</th>
#       <td>AREQ-17052</td>
#     </tr>
#     <tr>
#       <th>AREQ-17053</th>
#       <td>AREQ-17053</td>
#     </tr>
#     <tr>
#       <th>AREQ-17054</th>
#       <td>AREQ-17054</td>
#     </tr>
#     <tr>
#       <th>AREQ-17055</th>
#       <td>AREQ-17055</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>AREQ-24222</th>
#       <td>AREQ-24222</td>
#     </tr>
#     <tr>
#       <th>AREQ-24723</th>
#       <td>AREQ-24723</td>
#     </tr>
#     <tr>
#       <th>AREQ-24792</th>
#       <td>AREQ-24792</td>
#     </tr>
#     <tr>
#       <th>AREQ-25486</th>
#       <td>AREQ-25486</td>
#     </tr>
#     <tr>
#       <th>AREQ-26080</th>
#       <td>AREQ-26080</td>
#     </tr>
#     <tr>
#       <th>AREQ-26260</th>
#       <td>AREQ-26260</td>
#     </tr>
#     <tr>
#       <th>AREQ-26261</th>
#       <td>AREQ-26261</td>
#     </tr>
#     <tr>
#       <th>AREQ-26287</th>
#       <td>AREQ-26287</td>
#     </tr>
#     <tr>
#       <th>AREQ-26288</th>
#       <td>AREQ-26288</td>
#     </tr>
#     <tr>
#       <th>AREQ-26289</th>
#       <td>AREQ-26289</td>
#     </tr>
#     <tr>
#       <th>AREQ-26290</th>
#       <td>AREQ-26290</td>
#     </tr>
#     <tr>
#       <th>AREQ-26291</th>
#       <td>AREQ-26291</td>
#     </tr>
#     <tr>
#       <th>AREQ-26292</th>
#       <td>AREQ-26292</td>
#     </tr>
#     <tr>
#       <th>AREQ-26293</th>
#       <td>AREQ-26293</td>
#     </tr>
#     <tr>
#       <th>AREQ-26294</th>
#       <td>AREQ-26294</td>
#     </tr>
#     <tr>
#       <th>AREQ-26295</th>
#       <td>AREQ-26295</td>
#     </tr>
#     <tr>
#       <th>AREQ-26296</th>
#       <td>AREQ-26296</td>
#     </tr>
#     <tr>
#       <th>AREQ-26580</th>
#       <td>AREQ-26580</td>
#     </tr>
#     <tr>
#       <th>PREQ-21112</th>
#       <td>PREQ-21112</td>
#     </tr>
#     <tr>
#       <th>PREQ-21583</th>
#       <td>PREQ-21583</td>
#     </tr>
#     <tr>
#       <th>PREQ-21585</th>
#       <td>PREQ-21585</td>
#     </tr>
#     <tr>
#       <th>PREQ-22929</th>
#       <td>PREQ-22929</td>
#     </tr>
#     <tr>
#       <th>PREQ-23143</th>
#       <td>PREQ-23143</td>
#     </tr>
#     <tr>
#       <th>PREQ-23156</th>
#       <td>PREQ-23156</td>
#     </tr>
#     <tr>
#       <th>PREQ-24711</th>
#       <td>PREQ-24711</td>
#     </tr>
#     <tr>
#       <th>PREQ-24735</th>
#       <td>PREQ-24735</td>
#     </tr>
#     <tr>
#       <th>PREQ-24826</th>
#       <td>PREQ-24826</td>
#     </tr>
#     <tr>
#       <th>PREQ-24997</th>
#       <td>PREQ-24997</td>
#     </tr>
#     <tr>
#       <th>PREQ-25012</th>
#       <td>PREQ-25012</td>
#     </tr>
#     <tr>
#       <th>PREQ-27375</th>
#       <td>PREQ-27375</td>
#     </tr>
#   </tbody>
# </table>
# <p>285 rows × 1 columns</p>
# </div>

# %%
import pandas as pd
df2 = pd.read_excel("AREQs_AIA_ToPaul_Final.xlsx", sheetname=0)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AREQ-11225</th>
#       <td>AREQ-11225</td>
#     </tr>
#     <tr>
#       <th>AREQ-11429</th>
#       <td>AREQ-11429</td>
#     </tr>
#     <tr>
#       <th>AREQ-17028</th>
#       <td>AREQ-17028</td>
#     </tr>
#     <tr>
#       <th>AREQ-17029</th>
#       <td>AREQ-17029</td>
#     </tr>
#     <tr>
#       <th>AREQ-17030</th>
#       <td>AREQ-17030</td>
#     </tr>
#     <tr>
#       <th>AREQ-17031</th>
#       <td>AREQ-17031</td>
#     </tr>
#     <tr>
#       <th>AREQ-17032</th>
#       <td>AREQ-17032</td>
#     </tr>
#     <tr>
#       <th>AREQ-17033</th>
#       <td>AREQ-17033</td>
#     </tr>
#     <tr>
#       <th>AREQ-17034</th>
#       <td>AREQ-17034</td>
#     </tr>
#     <tr>
#       <th>AREQ-17035</th>
#       <td>AREQ-17035</td>
#     </tr>
#     <tr>
#       <th>AREQ-17036</th>
#       <td>AREQ-17036</td>
#     </tr>
#     <tr>
#       <th>AREQ-17037</th>
#       <td>AREQ-17037</td>
#     </tr>
#     <tr>
#       <th>AREQ-17038</th>
#       <td>AREQ-17038</td>
#     </tr>
#     <tr>
#       <th>AREQ-17039</th>
#       <td>AREQ-17039</td>
#     </tr>
#     <tr>
#       <th>AREQ-17040</th>
#       <td>AREQ-17040</td>
#     </tr>
#     <tr>
#       <th>AREQ-17041</th>
#       <td>AREQ-17041</td>
#     </tr>
#     <tr>
#       <th>AREQ-17042</th>
#       <td>AREQ-17042</td>
#     </tr>
#     <tr>
#       <th>AREQ-17043</th>
#       <td>AREQ-17043</td>
#     </tr>
#     <tr>
#       <th>AREQ-17044</th>
#       <td>AREQ-17044</td>
#     </tr>
#     <tr>
#       <th>AREQ-17045</th>
#       <td>AREQ-17045</td>
#     </tr>
#     <tr>
#       <th>AREQ-17046</th>
#       <td>AREQ-17046</td>
#     </tr>
#     <tr>
#       <th>AREQ-17047</th>
#       <td>AREQ-17047</td>
#     </tr>
#     <tr>
#       <th>AREQ-17048</th>
#       <td>AREQ-17048</td>
#     </tr>
#     <tr>
#       <th>AREQ-17049</th>
#       <td>AREQ-17049</td>
#     </tr>
#     <tr>
#       <th>AREQ-17050</th>
#       <td>AREQ-17050</td>
#     </tr>
#     <tr>
#       <th>AREQ-17051</th>
#       <td>AREQ-17051</td>
#     </tr>
#     <tr>
#       <th>AREQ-17052</th>
#       <td>AREQ-17052</td>
#     </tr>
#     <tr>
#       <th>AREQ-17053</th>
#       <td>AREQ-17053</td>
#     </tr>
#     <tr>
#       <th>AREQ-17054</th>
#       <td>AREQ-17054</td>
#     </tr>
#     <tr>
#       <th>AREQ-17055</th>
#       <td>AREQ-17055</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>AREQ-24222</th>
#       <td>AREQ-24222</td>
#     </tr>
#     <tr>
#       <th>AREQ-24723</th>
#       <td>AREQ-24723</td>
#     </tr>
#     <tr>
#       <th>AREQ-24792</th>
#       <td>AREQ-24792</td>
#     </tr>
#     <tr>
#       <th>AREQ-25486</th>
#       <td>AREQ-25486</td>
#     </tr>
#     <tr>
#       <th>AREQ-26080</th>
#       <td>AREQ-26080</td>
#     </tr>
#     <tr>
#       <th>AREQ-26260</th>
#       <td>AREQ-26260</td>
#     </tr>
#     <tr>
#       <th>AREQ-26261</th>
#       <td>AREQ-26261</td>
#     </tr>
#     <tr>
#       <th>AREQ-26287</th>
#       <td>AREQ-26287</td>
#     </tr>
#     <tr>
#       <th>AREQ-26288</th>
#       <td>AREQ-26288</td>
#     </tr>
#     <tr>
#       <th>AREQ-26289</th>
#       <td>AREQ-26289</td>
#     </tr>
#     <tr>
#       <th>AREQ-26290</th>
#       <td>AREQ-26290</td>
#     </tr>
#     <tr>
#       <th>AREQ-26291</th>
#       <td>AREQ-26291</td>
#     </tr>
#     <tr>
#       <th>AREQ-26292</th>
#       <td>AREQ-26292</td>
#     </tr>
#     <tr>
#       <th>AREQ-26293</th>
#       <td>AREQ-26293</td>
#     </tr>
#     <tr>
#       <th>AREQ-26294</th>
#       <td>AREQ-26294</td>
#     </tr>
#     <tr>
#       <th>AREQ-26295</th>
#       <td>AREQ-26295</td>
#     </tr>
#     <tr>
#       <th>AREQ-26296</th>
#       <td>AREQ-26296</td>
#     </tr>
#     <tr>
#       <th>AREQ-26580</th>
#       <td>AREQ-26580</td>
#     </tr>
#     <tr>
#       <th>PREQ-21112</th>
#       <td>PREQ-21112</td>
#     </tr>
#     <tr>
#       <th>PREQ-21583</th>
#       <td>PREQ-21583</td>
#     </tr>
#     <tr>
#       <th>PREQ-21585</th>
#       <td>PREQ-21585</td>
#     </tr>
#     <tr>
#       <th>PREQ-22929</th>
#       <td>PREQ-22929</td>
#     </tr>
#     <tr>
#       <th>PREQ-23143</th>
#       <td>PREQ-23143</td>
#     </tr>
#     <tr>
#       <th>PREQ-23156</th>
#       <td>PREQ-23156</td>
#     </tr>
#     <tr>
#       <th>PREQ-24711</th>
#       <td>PREQ-24711</td>
#     </tr>
#     <tr>
#       <th>PREQ-24735</th>
#       <td>PREQ-24735</td>
#     </tr>
#     <tr>
#       <th>PREQ-24826</th>
#       <td>PREQ-24826</td>
#     </tr>
#     <tr>
#       <th>PREQ-24997</th>
#       <td>PREQ-24997</td>
#     </tr>
#     <tr>
#       <th>PREQ-25012</th>
#       <td>PREQ-25012</td>
#     </tr>
#     <tr>
#       <th>PREQ-27375</th>
#       <td>PREQ-27375</td>
#     </tr>
#   </tbody>
# </table>
# <p>285 rows × 1 columns</p>
# </div>

# %%
def get_issue(jira, id, fields=None, expand=None):
    try:
        issue = jira.issue(id, fields, expand)
        log.logger.info("got issue %s", issue.key)
    except Exception as e:
        log.logger.error("Exceptiion processing issue %s, %s", id, e)
        issue = None
    return issue
        
items = [get_issue(jira, key) for key in sorted(df2['Key'])]
items
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AREQ-11225</th>
#       <td>AREQ-11225</td>
#     </tr>
#     <tr>
#       <th>AREQ-11429</th>
#       <td>AREQ-11429</td>
#     </tr>
#     <tr>
#       <th>AREQ-17028</th>
#       <td>AREQ-17028</td>
#     </tr>
#     <tr>
#       <th>AREQ-17029</th>
#       <td>AREQ-17029</td>
#     </tr>
#     <tr>
#       <th>AREQ-17030</th>
#       <td>AREQ-17030</td>
#     </tr>
#     <tr>
#       <th>AREQ-17031</th>
#       <td>AREQ-17031</td>
#     </tr>
#     <tr>
#       <th>AREQ-17032</th>
#       <td>AREQ-17032</td>
#     </tr>
#     <tr>
#       <th>AREQ-17033</th>
#       <td>AREQ-17033</td>
#     </tr>
#     <tr>
#       <th>AREQ-17034</th>
#       <td>AREQ-17034</td>
#     </tr>
#     <tr>
#       <th>AREQ-17035</th>
#       <td>AREQ-17035</td>
#     </tr>
#     <tr>
#       <th>AREQ-17036</th>
#       <td>AREQ-17036</td>
#     </tr>
#     <tr>
#       <th>AREQ-17037</th>
#       <td>AREQ-17037</td>
#     </tr>
#     <tr>
#       <th>AREQ-17038</th>
#       <td>AREQ-17038</td>
#     </tr>
#     <tr>
#       <th>AREQ-17039</th>
#       <td>AREQ-17039</td>
#     </tr>
#     <tr>
#       <th>AREQ-17040</th>
#       <td>AREQ-17040</td>
#     </tr>
#     <tr>
#       <th>AREQ-17041</th>
#       <td>AREQ-17041</td>
#     </tr>
#     <tr>
#       <th>AREQ-17042</th>
#       <td>AREQ-17042</td>
#     </tr>
#     <tr>
#       <th>AREQ-17043</th>
#       <td>AREQ-17043</td>
#     </tr>
#     <tr>
#       <th>AREQ-17044</th>
#       <td>AREQ-17044</td>
#     </tr>
#     <tr>
#       <th>AREQ-17045</th>
#       <td>AREQ-17045</td>
#     </tr>
#     <tr>
#       <th>AREQ-17046</th>
#       <td>AREQ-17046</td>
#     </tr>
#     <tr>
#       <th>AREQ-17047</th>
#       <td>AREQ-17047</td>
#     </tr>
#     <tr>
#       <th>AREQ-17048</th>
#       <td>AREQ-17048</td>
#     </tr>
#     <tr>
#       <th>AREQ-17049</th>
#       <td>AREQ-17049</td>
#     </tr>
#     <tr>
#       <th>AREQ-17050</th>
#       <td>AREQ-17050</td>
#     </tr>
#     <tr>
#       <th>AREQ-17051</th>
#       <td>AREQ-17051</td>
#     </tr>
#     <tr>
#       <th>AREQ-17052</th>
#       <td>AREQ-17052</td>
#     </tr>
#     <tr>
#       <th>AREQ-17053</th>
#       <td>AREQ-17053</td>
#     </tr>
#     <tr>
#       <th>AREQ-17054</th>
#       <td>AREQ-17054</td>
#     </tr>
#     <tr>
#       <th>AREQ-17055</th>
#       <td>AREQ-17055</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>AREQ-24222</th>
#       <td>AREQ-24222</td>
#     </tr>
#     <tr>
#       <th>AREQ-24723</th>
#       <td>AREQ-24723</td>
#     </tr>
#     <tr>
#       <th>AREQ-24792</th>
#       <td>AREQ-24792</td>
#     </tr>
#     <tr>
#       <th>AREQ-25486</th>
#       <td>AREQ-25486</td>
#     </tr>
#     <tr>
#       <th>AREQ-26080</th>
#       <td>AREQ-26080</td>
#     </tr>
#     <tr>
#       <th>AREQ-26260</th>
#       <td>AREQ-26260</td>
#     </tr>
#     <tr>
#       <th>AREQ-26261</th>
#       <td>AREQ-26261</td>
#     </tr>
#     <tr>
#       <th>AREQ-26287</th>
#       <td>AREQ-26287</td>
#     </tr>
#     <tr>
#       <th>AREQ-26288</th>
#       <td>AREQ-26288</td>
#     </tr>
#     <tr>
#       <th>AREQ-26289</th>
#       <td>AREQ-26289</td>
#     </tr>
#     <tr>
#       <th>AREQ-26290</th>
#       <td>AREQ-26290</td>
#     </tr>
#     <tr>
#       <th>AREQ-26291</th>
#       <td>AREQ-26291</td>
#     </tr>
#     <tr>
#       <th>AREQ-26292</th>
#       <td>AREQ-26292</td>
#     </tr>
#     <tr>
#       <th>AREQ-26293</th>
#       <td>AREQ-26293</td>
#     </tr>
#     <tr>
#       <th>AREQ-26294</th>
#       <td>AREQ-26294</td>
#     </tr>
#     <tr>
#       <th>AREQ-26295</th>
#       <td>AREQ-26295</td>
#     </tr>
#     <tr>
#       <th>AREQ-26296</th>
#       <td>AREQ-26296</td>
#     </tr>
#     <tr>
#       <th>AREQ-26580</th>
#       <td>AREQ-26580</td>
#     </tr>
#     <tr>
#       <th>PREQ-21112</th>
#       <td>PREQ-21112</td>
#     </tr>
#     <tr>
#       <th>PREQ-21583</th>
#       <td>PREQ-21583</td>
#     </tr>
#     <tr>
#       <th>PREQ-21585</th>
#       <td>PREQ-21585</td>
#     </tr>
#     <tr>
#       <th>PREQ-22929</th>
#       <td>PREQ-22929</td>
#     </tr>
#     <tr>
#       <th>PREQ-23143</th>
#       <td>PREQ-23143</td>
#     </tr>
#     <tr>
#       <th>PREQ-23156</th>
#       <td>PREQ-23156</td>
#     </tr>
#     <tr>
#       <th>PREQ-24711</th>
#       <td>PREQ-24711</td>
#     </tr>
#     <tr>
#       <th>PREQ-24735</th>
#       <td>PREQ-24735</td>
#     </tr>
#     <tr>
#       <th>PREQ-24826</th>
#       <td>PREQ-24826</td>
#     </tr>
#     <tr>
#       <th>PREQ-24997</th>
#       <td>PREQ-24997</td>
#     </tr>
#     <tr>
#       <th>PREQ-25012</th>
#       <td>PREQ-25012</td>
#     </tr>
#     <tr>
#       <th>PREQ-27375</th>
#       <td>PREQ-27375</td>
#     </tr>
#   </tbody>
# </table>
# <p>285 rows × 1 columns</p>
# </div>

# %%
keys=[item.key for item in items]
s = pd.DataFrame(items,keys)
s
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>AREQ-11225</th>
#       <td>AREQ-11225</td>
#     </tr>
#     <tr>
#       <th>AREQ-11429</th>
#       <td>AREQ-11429</td>
#     </tr>
#     <tr>
#       <th>AREQ-17028</th>
#       <td>AREQ-17028</td>
#     </tr>
#     <tr>
#       <th>AREQ-17029</th>
#       <td>AREQ-17029</td>
#     </tr>
#     <tr>
#       <th>AREQ-17030</th>
#       <td>AREQ-17030</td>
#     </tr>
#     <tr>
#       <th>AREQ-17031</th>
#       <td>AREQ-17031</td>
#     </tr>
#     <tr>
#       <th>AREQ-17032</th>
#       <td>AREQ-17032</td>
#     </tr>
#     <tr>
#       <th>AREQ-17033</th>
#       <td>AREQ-17033</td>
#     </tr>
#     <tr>
#       <th>AREQ-17034</th>
#       <td>AREQ-17034</td>
#     </tr>
#     <tr>
#       <th>AREQ-17035</th>
#       <td>AREQ-17035</td>
#     </tr>
#     <tr>
#       <th>AREQ-17036</th>
#       <td>AREQ-17036</td>
#     </tr>
#     <tr>
#       <th>AREQ-17037</th>
#       <td>AREQ-17037</td>
#     </tr>
#     <tr>
#       <th>AREQ-17038</th>
#       <td>AREQ-17038</td>
#     </tr>
#     <tr>
#       <th>AREQ-17039</th>
#       <td>AREQ-17039</td>
#     </tr>
#     <tr>
#       <th>AREQ-17040</th>
#       <td>AREQ-17040</td>
#     </tr>
#     <tr>
#       <th>AREQ-17041</th>
#       <td>AREQ-17041</td>
#     </tr>
#     <tr>
#       <th>AREQ-17042</th>
#       <td>AREQ-17042</td>
#     </tr>
#     <tr>
#       <th>AREQ-17043</th>
#       <td>AREQ-17043</td>
#     </tr>
#     <tr>
#       <th>AREQ-17044</th>
#       <td>AREQ-17044</td>
#     </tr>
#     <tr>
#       <th>AREQ-17045</th>
#       <td>AREQ-17045</td>
#     </tr>
#     <tr>
#       <th>AREQ-17046</th>
#       <td>AREQ-17046</td>
#     </tr>
#     <tr>
#       <th>AREQ-17047</th>
#       <td>AREQ-17047</td>
#     </tr>
#     <tr>
#       <th>AREQ-17048</th>
#       <td>AREQ-17048</td>
#     </tr>
#     <tr>
#       <th>AREQ-17049</th>
#       <td>AREQ-17049</td>
#     </tr>
#     <tr>
#       <th>AREQ-17050</th>
#       <td>AREQ-17050</td>
#     </tr>
#     <tr>
#       <th>AREQ-17051</th>
#       <td>AREQ-17051</td>
#     </tr>
#     <tr>
#       <th>AREQ-17052</th>
#       <td>AREQ-17052</td>
#     </tr>
#     <tr>
#       <th>AREQ-17053</th>
#       <td>AREQ-17053</td>
#     </tr>
#     <tr>
#       <th>AREQ-17054</th>
#       <td>AREQ-17054</td>
#     </tr>
#     <tr>
#       <th>AREQ-17055</th>
#       <td>AREQ-17055</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>AREQ-24222</th>
#       <td>AREQ-24222</td>
#     </tr>
#     <tr>
#       <th>AREQ-24723</th>
#       <td>AREQ-24723</td>
#     </tr>
#     <tr>
#       <th>AREQ-24792</th>
#       <td>AREQ-24792</td>
#     </tr>
#     <tr>
#       <th>AREQ-25486</th>
#       <td>AREQ-25486</td>
#     </tr>
#     <tr>
#       <th>AREQ-26080</th>
#       <td>AREQ-26080</td>
#     </tr>
#     <tr>
#       <th>AREQ-26260</th>
#       <td>AREQ-26260</td>
#     </tr>
#     <tr>
#       <th>AREQ-26261</th>
#       <td>AREQ-26261</td>
#     </tr>
#     <tr>
#       <th>AREQ-26287</th>
#       <td>AREQ-26287</td>
#     </tr>
#     <tr>
#       <th>AREQ-26288</th>
#       <td>AREQ-26288</td>
#     </tr>
#     <tr>
#       <th>AREQ-26289</th>
#       <td>AREQ-26289</td>
#     </tr>
#     <tr>
#       <th>AREQ-26290</th>
#       <td>AREQ-26290</td>
#     </tr>
#     <tr>
#       <th>AREQ-26291</th>
#       <td>AREQ-26291</td>
#     </tr>
#     <tr>
#       <th>AREQ-26292</th>
#       <td>AREQ-26292</td>
#     </tr>
#     <tr>
#       <th>AREQ-26293</th>
#       <td>AREQ-26293</td>
#     </tr>
#     <tr>
#       <th>AREQ-26294</th>
#       <td>AREQ-26294</td>
#     </tr>
#     <tr>
#       <th>AREQ-26295</th>
#       <td>AREQ-26295</td>
#     </tr>
#     <tr>
#       <th>AREQ-26296</th>
#       <td>AREQ-26296</td>
#     </tr>
#     <tr>
#       <th>AREQ-26580</th>
#       <td>AREQ-26580</td>
#     </tr>
#     <tr>
#       <th>PREQ-21112</th>
#       <td>PREQ-21112</td>
#     </tr>
#     <tr>
#       <th>PREQ-21583</th>
#       <td>PREQ-21583</td>
#     </tr>
#     <tr>
#       <th>PREQ-21585</th>
#       <td>PREQ-21585</td>
#     </tr>
#     <tr>
#       <th>PREQ-22929</th>
#       <td>PREQ-22929</td>
#     </tr>
#     <tr>
#       <th>PREQ-23143</th>
#       <td>PREQ-23143</td>
#     </tr>
#     <tr>
#       <th>PREQ-23156</th>
#       <td>PREQ-23156</td>
#     </tr>
#     <tr>
#       <th>PREQ-24711</th>
#       <td>PREQ-24711</td>
#     </tr>
#     <tr>
#       <th>PREQ-24735</th>
#       <td>PREQ-24735</td>
#     </tr>
#     <tr>
#       <th>PREQ-24826</th>
#       <td>PREQ-24826</td>
#     </tr>
#     <tr>
#       <th>PREQ-24997</th>
#       <td>PREQ-24997</td>
#     </tr>
#     <tr>
#       <th>PREQ-25012</th>
#       <td>PREQ-25012</td>
#     </tr>
#     <tr>
#       <th>PREQ-27375</th>
#       <td>PREQ-27375</td>
#     </tr>
#   </tbody>
# </table>
# <p>285 rows × 1 columns</p>
# </div>

# %%
df2.iloc[0:2,[1,3,5,1]]
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Key</th>
#       <th>Resolution</th>
#       <th>Summary</th>
#       <th>Key</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>AREQ-17059</td>
#       <td>Product Change</td>
#       <td>AREQ-16492 [N][Cherrytrail-T4] Device Health M...</td>
#       <td>AREQ-17059</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>AREQ-17058</td>
#       <td>Product Change</td>
#       <td>AREQ-16491 [N][Cherrytrail-T4] Customized Lock...</td>
#       <td>AREQ-17058</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
s.head
# Out:
# <bound method NDFrame.head of                      0
# AREQ-11225  AREQ-11225
# AREQ-11429  AREQ-11429
# AREQ-17028  AREQ-17028
# AREQ-17029  AREQ-17029
# AREQ-17030  AREQ-17030
# AREQ-17031  AREQ-17031
# AREQ-17032  AREQ-17032
# AREQ-17033  AREQ-17033
# AREQ-17034  AREQ-17034
# AREQ-17035  AREQ-17035
# AREQ-17036  AREQ-17036
# AREQ-17037  AREQ-17037
# AREQ-17038  AREQ-17038
# AREQ-17039  AREQ-17039
# AREQ-17040  AREQ-17040
# AREQ-17041  AREQ-17041
# AREQ-17042  AREQ-17042
# AREQ-17043  AREQ-17043
# AREQ-17044  AREQ-17044
# AREQ-17045  AREQ-17045
# AREQ-17046  AREQ-17046
# AREQ-17047  AREQ-17047
# AREQ-17048  AREQ-17048
# AREQ-17049  AREQ-17049
# AREQ-17050  AREQ-17050
# AREQ-17051  AREQ-17051
# AREQ-17052  AREQ-17052
# AREQ-17053  AREQ-17053
# AREQ-17054  AREQ-17054
# AREQ-17055  AREQ-17055
# ...                ...
# AREQ-24222  AREQ-24222
# AREQ-24723  AREQ-24723
# AREQ-24792  AREQ-24792
# AREQ-25486  AREQ-25486
# AREQ-26080  AREQ-26080
# AREQ-26260  AREQ-26260
# AREQ-26261  AREQ-26261
# AREQ-26287  AREQ-26287
# AREQ-26288  AREQ-26288
# AREQ-26289  AREQ-26289
# AREQ-26290  AREQ-26290
# AREQ-26291  AREQ-26291
# AREQ-26292  AREQ-26292
# AREQ-26293  AREQ-26293
# AREQ-26294  AREQ-26294
# AREQ-26295  AREQ-26295
# AREQ-26296  AREQ-26296
# AREQ-26580  AREQ-26580
# PREQ-21112  PREQ-21112
# PREQ-21583  PREQ-21583
# PREQ-21585  PREQ-21585
# PREQ-22929  PREQ-22929
# PREQ-23143  PREQ-23143
# PREQ-23156  PREQ-23156
# PREQ-24711  PREQ-24711
# PREQ-24735  PREQ-24735
# PREQ-24826  PREQ-24826
# PREQ-24997  PREQ-24997
# PREQ-25012  PREQ-25012
# PREQ-27375  PREQ-27375
#
# [285 rows x 1 columns]>

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8543)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# C:\Users\pfhanchx\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2133             try:
# -> 2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4363)()
#
# KeyError: 'AREQ-11225'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4279)()
#
# pandas\src\hashtable_class_helper.pxi in pandas.hashtable.Int64HashTable.get_item (pandas\hashtable.c:8543)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-15-1c9e8b297310> in <module>()
# ----> 1 s['AREQ-11225']
#
# C:\Users\pfhanchx\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    2057             return self._getitem_multilevel(key)
#    2058         else:
# -> 2059             return self._getitem_column(key)
#    2060
#    2061     def _getitem_column(self, key):
#
# C:\Users\pfhanchx\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\frame.py in _getitem_column(self, key)
#    2064         # get column
#    2065         if self.columns.is_unique:
# -> 2066             return self._get_item_cache(key)
#    2067
#    2068         # duplicate columns & possible reduce dimensionality
#
# C:\Users\pfhanchx\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\generic.py in _get_item_cache(self, item)
#    1384         res = cache.get(item)
#    1385         if res is None:
# -> 1386             values = self._data.get(item)
#    1387             res = self._box_item_values(item, values)
#    1388             cache[item] = res
#
# C:\Users\pfhanchx\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\core\internals.py in get(self, item, fastpath)
#    3541
#    3542             if not isnull(item):
# -> 3543                 loc = self.items.get_loc(item)
#    3544             else:
#    3545                 indexer = np.arange(len(self.items))[isnull(self.items)]
#
# C:\Users\pfhanchx\AppData\Local\Continuum\Anaconda3\lib\site-packages\pandas\indexes\base.py in get_loc(self, key, method, tolerance)
#    2134                 return self._engine.get_loc(key)
#    2135             except KeyError:
# -> 2136                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2137
#    2138         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4433)()
#
# pandas\index.pyx in pandas.index.IndexEngine.get_loc (pandas\index.c:4363)()
#
# KeyError: 'AREQ-11225'

# %%
# sorted(df['Key'])
